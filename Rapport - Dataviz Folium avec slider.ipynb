# %% [markdown]
# ## 0- Objectif du notebook

# %% [markdown]
# Ce notebook vise à afficher sous folium l'évolution des incdendies par état, avec l'aide d'un slider et l'utilisation d'une échelle de couleurs.

# %% [markdown]
# ## 1- Chargement des librairies et du jeu de données initial

# %%
import pandas as pd
import numpy as np
import folium
import geoplot as gplt
import geopandas as gpd
import geoplot.crs as gcrs

import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\geopandas\_compat.py:111: UserWarning: The Shapely GEOS version (3.10.2-CAPI-1.16.0) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %%
df = pd.read_csv('Fires_filter.csv', index_col = 'OBJECTID')
df.DISCOVERY_DATE = pd.to_datetime(df.DISCOVERY_DATE)
df.CONT_DATE = pd.to_datetime(df.CONT_DATE)

# %% [markdown]
# Nous allons travailler 3 cartes Folium permettant de suivre les métriques suivantes :
# - Le nombre cumulé de feux par état
# - La surface brûlée cumulée par état
# - Le pourcentage cumulé du territoire brûlé par état

# %% [markdown]
# ## 2a- Evol du nombre de feux : préparation des données

# %% [markdown]
# Chargement de la carte des US au format Geopandas

# %%
usa = gpd.read_file("../maps/cb_2020_us_state_20m.shp")

# %% [markdown]
# Constitution du jeu de données de travail avec le décompte de feux par année et par état

# %%
#df_mega_count = df.query("FIRE_SIZE_CLASS == 'G'").groupby(['FIRE_YEAR', 'STATE'], as_index = False)[['FIRE_SIZE_CLASS']].count()
df_mega_count = df.groupby(['FIRE_YEAR', 'STATE'], as_index = False)[['FIRE_SIZE_CLASS']].count()

# %% [markdown]
# Ajout d'une colonne de sommme cumulée du nombre de feux reportés par année et par état

# %%
df_mega_count['cumsum'] = df_mega_count.FIRE_SIZE_CLASS

for i in df_mega_count.STATE.unique().tolist():
    list_index = df_mega_count[df_mega_count.STATE == i].index
    base = df_mega_count.iloc[list_index[0], 2]
    for j in list_index[1:]:
        df_mega_count.iloc[j, 3] = base + df_mega_count.iloc[j, 3]
        base = df_mega_count.iloc[j, 3]

# %% [markdown]
# Merge avec les données de l'objet Geopandas afin d'avoir le nom des états

# %%
df_mega_count = df_mega_count.merge(usa, left_on = 'STATE', right_on = 'STUSPS')

# %% [markdown]
# Transformation de la donnée "année" en nombre de secondes depuis l'epoch

# %%
df_mega_count['date_sec'] = pd.to_datetime(df_mega_count['FIRE_YEAR'], format = '%Y').apply(lambda x : pd.Timestamp(x).timestamp()).astype(int)

# %% [markdown]
# ## 2b- Evol des surfaces brûlées : préparation des données

# %% [markdown]
# Chargement de la carte des US au format Geopandas

# %%
usa = gpd.read_file("../maps/cb_2020_us_state_20m.shp")

# %% [markdown]
# Constitution du jeu de données de travail avec le décompte de feux par année et par état

# %%
#df_mega_count = df.query("FIRE_SIZE_CLASS == 'G'").groupby(['FIRE_YEAR', 'STATE'], as_index = False)[['FIRE_SIZE_CLASS']].count()
df_mega_surf = df.groupby(['FIRE_YEAR', 'STATE'], as_index = False)[['FIRE_SIZE']].sum()

# %% [markdown]
# Ajout d'une colonne de sommme cumulée du nombre de feux reportés par année et par état

# %%
df_mega_surf['cumsum'] = df_mega_surf.FIRE_SIZE

for i in df_mega_surf.STATE.unique().tolist():
    list_index = df_mega_surf[df_mega_surf.STATE == i].index
    base = df_mega_surf.iloc[list_index[0], 2]
    for j in list_index[1:]:
        df_mega_surf.iloc[j, 3] = base + df_mega_surf.iloc[j, 3]
        base = df_mega_surf.iloc[j, 3]

df_mega_surf['cumsum'] = np.round(df_mega_surf['cumsum']*0.00404686, 0)
df_mega_surf['cumsum'] = df_mega_surf['cumsum'].astype(int)

# %%
df_mega_surf
# Out:
#       FIRE_YEAR STATE    FIRE_SIZE  cumsum
# 0          1992    AK   142717.400     578
# 1          1992    AL     1253.200       5
# 2          1992    AR     1478.500       6
# 3          1992    AZ    42593.650     172
# 4          1992    CA   296439.800    1200
# ...         ...   ...          ...     ...
# 1209       2015    VT      346.429       6
# 1210       2015    WA  1161646.380   19353
# 1211       2015    WI     2721.440     359
# 1212       2015    WV    17251.370    2334
# 1213       2015    WY    36821.225    9718
#
# [1214 rows x 4 columns]

# %% [markdown]
# Merge avec les données de l'objet Geopandas afin d'avoir le nom des états

# %%
df_mega_surf = df_mega_surf.merge(usa, left_on = 'STATE', right_on = 'STUSPS')

# %% [markdown]
# Transformation de la donnée "année" en nombre de secondes depuis l'epoch

# %%
df_mega_surf['date_sec'] = pd.to_datetime(df_mega_surf['FIRE_YEAR'], format = '%Y').apply(lambda x : pd.Timestamp(x).timestamp()).astype(int)

# %% [markdown]
# ## 2c- Evol du ratio de surfaces brûlées : préparation des données

# %% [markdown]
# Chargement de la carte des US au format Geopandas

# %%
usa = gpd.read_file("../maps/cb_2020_us_state_20m.shp")

# %% [markdown]
# Import données de surface de chaque état

# %%
us_area = pd.read_csv('US_area.csv', sep = ";", names = ['STATE', 'AREA'])

# %%
us_area.AREA = np.round(us_area.AREA * 2.58999, 0).astype(int)
us_area.STATE = us_area.STATE.apply(lambda x: x.replace(" ", ""))
us_area.set_index('STATE', inplace = True)

# %%
us_area.sample(5)
# Out:
#          AREA
# STATE
# KS     131681
# FL      86900
# KY      63942
# NM     195318
# WI      87410

# %%
us_area.drop('DC', axis = 0, inplace = True)

# %%
us_area.loc['DC'] = 177

# %%
us_area.loc['PR'] = 9104

# %% [markdown]
# Constitution du jeu de données de travail avec le décompte de feux par année et par état

# %%
df_mega_surf = df.groupby(['FIRE_YEAR', 'STATE'], as_index = False)[['FIRE_SIZE']].sum()

# %%
df_mega_surf
# Out:
#       FIRE_YEAR STATE    FIRE_SIZE
# 0          1992    AK   142717.400
# 1          1992    AL     1253.200
# 2          1992    AR     1478.500
# 3          1992    AZ    42593.650
# 4          1992    CA   296439.800
# ...         ...   ...          ...
# 1209       2015    VT      346.429
# 1210       2015    WA  1161646.380
# 1211       2015    WI     2721.440
# 1212       2015    WV    17251.370
# 1213       2015    WY    36821.225
#
# [1214 rows x 3 columns]

# %% [markdown]
# Ajout d'une colonne de sommme cumulée du nombre de feux reportés par année et par état

# %%
df_mega_surf.FIRE_SIZE = df_mega_surf.FIRE_SIZE * 0.00404686

# %%
df_mega_surf['cumratio'] = df_mega_surf.FIRE_SIZE

for i in df_mega_surf.STATE.unique().tolist():
    list_index = df_mega_surf[df_mega_surf.STATE == i].index
    base = df_mega_surf.iloc[list_index[0], 2]
    df_mega_surf.iloc[list_index[0], 3] = base / us_area.loc[i]
    for j in list_index[1:]:
        df_mega_surf.iloc[j, 3] = (base + df_mega_surf.iloc[j, 3])
        base = df_mega_surf.iloc[j, 3]
        df_mega_surf.iloc[j, 3] = (base + df_mega_surf.iloc[j, 3]) / us_area.loc[i]
        
df_mega_surf['cumratio'] = np.round(df_mega_surf['cumratio'] * 100, 2)

# %%
df_mega_surf
# Out:
#       FIRE_YEAR STATE    FIRE_SIZE  cumratio STATEFP   STATENS     AFFGEOID  \
# 0          1992    AK   577.557337      0.06      02  01785533  0400000US02
# 1          1993    AK  2780.967794      0.73      02  01785533  0400000US02
# 2          1994    AK  1060.135275      0.96      02  01785533  0400000US02
# 3          1995    AK   177.908464      1.00      02  01785533  0400000US02
# 4          1996    AK  2423.248437      1.53      02  01785533  0400000US02
# ...         ...   ...          ...       ...     ...       ...          ...
# 1209       2011    RI     0.113474      0.18      44  01219835  0400000US44
# 1210       2012    RI     0.161510      0.19      44  01219835  0400000US44
# 1211       2013    RI     0.067583      0.20      44  01219835  0400000US44
# 1212       2014    RI     0.094292      0.21      44  01219835  0400000US44
# 1213       2015    RI     0.493029      0.27      44  01219835  0400000US44
#
#      GEOID STUSPS          NAME LSAD          ALAND        AWATER  \
# 0       02     AK        Alaska   00  1478941109938  245380162784
# 1       02     AK        Alaska   00  1478941109938  245380162784
# 2       02     AK        Alaska   00  1478941109938  245380162784
# 3       02     AK        Alaska   00  1478941109938  245380162784
# 4       02     AK        Alaska   00  1478941109938  245380162784
# ...    ...    ...           ...  ...            ...           ...
# 1209    44     RI  Rhode Island   00     2677759219    1323691129
# 1210    44     RI  Rhode Island   00     2677759219    1323691129
# 1211    44     RI  Rhode Island   00     2677759219    1323691129
# 1212    44     RI  Rhode Island   00     2677759219    1323691129
# 1213    44     RI  Rhode Island   00     2677759219    1323691129
#
#                                                geometry    date_sec     colour
# 0     MULTIPOLYGON (((179.48132 51.97530, 179.58286 ...   694224000  #ffffcaff
# 1     MULTIPOLYGON (((179.48132 51.97530, 179.58286 ...   725846400  #fffbc1ff
# 2     MULTIPOLYGON (((179.48132 51.97530, 179.58286 ...   757382400  #fffec9ff
# 3     MULTIPOLYGON (((179.48132 51.97530, 179.58286 ...   788918400  #ffffccff
# 4     MULTIPOLYGON (((179.48132 51.97530, 179.58286 ...   820454400  #fffcc4ff
# ...                                                 ...         ...        ...
# 1209  MULTIPOLYGON (((-71.63147 41.16668, -71.59334 ...  1293840000  #ffffccff
# 1210  MULTIPOLYGON (((-71.63147 41.16668, -71.59334 ...  1325376000  #ffffccff
# 1211  MULTIPOLYGON (((-71.63147 41.16668, -71.59334 ...  1356998400  #ffffccff
# 1212  MULTIPOLYGON (((-71.63147 41.16668, -71.59334 ...  1388534400  #ffffccff
# 1213  MULTIPOLYGON (((-71.63147 41.16668, -71.59334 ...  1420070400  #ffffcbff
#
# [1214 rows x 16 columns]

# %%
df_mega_surf.cumratio.max()
# Out:
# 56.68

# %%
df_mega_surf[df_mega_surf.STATE ==  'TX']
# Out:
#       FIRE_YEAR STATE     FIRE_SIZE  cumratio STATEFP   STATENS     AFFGEOID  \
# 1015       1992    TX    136.016179      0.03      48  01779801  0400000US48
# 1016       1993    TX    472.971502      0.29      48  01779801  0400000US48
# 1017       1994    TX    286.993194      0.43      48  01779801  0400000US48
# 1018       1995    TX    228.125950      0.53      48  01779801  0400000US48
# 1019       1996    TX    875.024210      0.95      48  01779801  0400000US48
# 1020       1997    TX    189.315753      1.04      48  01779801  0400000US48
# 1021       1998    TX    552.604399      1.30      48  01779801  0400000US48
# 1022       1999    TX    242.925721      1.42      48  01779801  0400000US48
# 1023       2000    TX    735.261043      1.76      48  01779801  0400000US48
# 1024       2001    TX    373.226520      1.94      48  01779801  0400000US48
# 1025       2002    TX    177.226568      2.03      48  01779801  0400000US48
# 1026       2003    TX    220.016245      2.13      48  01779801  0400000US48
# 1027       2004    TX    139.832772      2.20      48  01779801  0400000US48
# 1028       2005    TX   1168.940974      2.75      48  01779801  0400000US48
# 1029       2006    TX   7497.832006      6.31      48  01779801  0400000US48
# 1030       2007    TX    546.461872      6.57      48  01779801  0400000US48
# 1031       2008    TX   6003.177359      9.42      48  01779801  0400000US48
# 1032       2009    TX   2257.316169     10.49      48  01779801  0400000US48
# 1033       2010    TX    963.970267     10.95      48  01779801  0400000US48
# 1034       2011    TX  14158.850051     17.66      48  01779801  0400000US48
# 1035       2012    TX    660.103164     17.98      48  01779801  0400000US48
# 1036       2013    TX    290.321413     18.11      48  01779801  0400000US48
# 1037       2014    TX    582.112604     18.39      48  01779801  0400000US48
# 1038       2015    TX    844.829495     18.79      48  01779801  0400000US48
#
#      GEOID STUSPS   NAME LSAD         ALAND       AWATER  \
# 1015    48     TX  Texas   00  676680588914  18979352230
# 1016    48     TX  Texas   00  676680588914  18979352230
# 1017    48     TX  Texas   00  676680588914  18979352230
# 1018    48     TX  Texas   00  676680588914  18979352230
# 1019    48     TX  Texas   00  676680588914  18979352230
# 1020    48     TX  Texas   00  676680588914  18979352230
# 1021    48     TX  Texas   00  676680588914  18979352230
# 1022    48     TX  Texas   00  676680588914  18979352230
# 1023    48     TX  Texas   00  676680588914  18979352230
# 1024    48     TX  Texas   00  676680588914  18979352230
# 1025    48     TX  Texas   00  676680588914  18979352230
# 1026    48     TX  Texas   00  676680588914  18979352230
# 1027    48     TX  Texas   00  676680588914  18979352230
# 1028    48     TX  Texas   00  676680588914  18979352230
# 1029    48     TX  Texas   00  676680588914  18979352230
# 1030    48     TX  Texas   00  676680588914  18979352230
# 1031    48     TX  Texas   00  676680588914  18979352230
# 1032    48     TX  Texas   00  676680588914  18979352230
# 1033    48     TX  Texas   00  676680588914  18979352230
# 1034    48     TX  Texas   00  676680588914  18979352230
# 1035    48     TX  Texas   00  676680588914  18979352230
# 1036    48     TX  Texas   00  676680588914  18979352230
# 1037    48     TX  Texas   00  676680588914  18979352230
# 1038    48     TX  Texas   00  676680588914  18979352230
#
#                                                geometry    date_sec     colour
# 1015  POLYGON ((-106.62345 31.91403, -106.63011 31.9...   694224000  #ffffcbff
# 1016  POLYGON ((-106.62345 31.91403, -106.63011 31.9...   725846400  #fffec8ff
# 1017  POLYGON ((-106.62345 31.91403, -106.63011 31.9...   757382400  #ffffcaff
# 1018  POLYGON ((-106.62345 31.91403, -106.63011 31.9...   788918400  #ffffcbff
# 1019  POLYGON ((-106.62345 31.91403, -106.63011 31.9...   820454400  #fffdc6ff
# 1020  POLYGON ((-106.62345 31.91403, -106.63011 31.9...   852076800  #ffffcbff
# 1021  POLYGON ((-106.62345 31.91403, -106.63011 31.9...   883612800  #fffec8ff
# 1022  POLYGON ((-106.62345 31.91403, -106.63011 31.9...   915148800  #ffffcaff
# 1023  POLYGON ((-106.62345 31.91403, -106.63011 31.9...   946684800  #fffdc7ff
# 1024  POLYGON ((-106.62345 31.91403, -106.63011 31.9...   978307200  #fffecaff
# 1025  POLYGON ((-106.62345 31.91403, -106.63011 31.9...  1009843200  #ffffcbff
# 1026  POLYGON ((-106.62345 31.91403, -106.63011 31.9...  1041379200  #ffffcbff
# 1027  POLYGON ((-106.62345 31.91403, -106.63011 31.9...  1072915200  #ffffcbff
# 1028  POLYGON ((-106.62345 31.91403, -106.63011 31.9...  1104537600  #fffcc4ff
# 1029  POLYGON ((-106.62345 31.91403, -106.63011 31.9...  1136073600  #ffe996ff
# 1030  POLYGON ((-106.62345 31.91403, -106.63011 31.9...  1167609600  #fffec8ff
# 1031  POLYGON ((-106.62345 31.91403, -106.63011 31.9...  1199145600  #ffeea1ff
# 1032  POLYGON ((-106.62345 31.91403, -106.63011 31.9...  1230768000  #fff9bcff
# 1033  POLYGON ((-106.62345 31.91403, -106.63011 31.9...  1262304000  #fffdc5ff
# 1034  POLYGON ((-106.62345 31.91403, -106.63011 31.9...  1293840000  #fecd68ff
# 1035  POLYGON ((-106.62345 31.91403, -106.63011 31.9...  1325376000  #fffdc7ff
# 1036  POLYGON ((-106.62345 31.91403, -106.63011 31.9...  1356998400  #ffffcaff
# 1037  POLYGON ((-106.62345 31.91403, -106.63011 31.9...  1388534400  #fffec8ff
# 1038  POLYGON ((-106.62345 31.91403, -106.63011 31.9...  1420070400  #fffdc6ff

# %% [markdown]
# Merge avec les données de l'objet Geopandas afin d'avoir le nom des états

# %%
df_mega_surf = df_mega_surf.merge(usa, left_on = 'STATE', right_on = 'STUSPS')

# %% [markdown]
# Transformation de la donnée "année" en nombre de secondes depuis l'epoch

# %%
df_mega_surf['date_sec'] = pd.to_datetime(df_mega_surf['FIRE_YEAR'], format = '%Y').apply(lambda x : pd.Timestamp(x).timestamp()).astype(int)

# %%
df_mega_surf.iloc[df_mega_surf.cumratio.nlargest(10).index]
# Out:
#      FIRE_YEAR STATE    FIRE_SIZE  cumratio STATEFP   STATENS     AFFGEOID  \
# 47        2015    AL   124.779708     91.23      01  01779775  0400000US01
# 143       2015    CO    92.277918     89.32      08  01779779  0400000US08
# 142       2014    CO    99.934415     88.21      08  01779779  0400000US08
# 46        2014    AL   153.624896     88.17      01  01779775  0400000US01
# 141       2013    CO   656.118343     87.02      08  01779779  0400000US08
# 45        2013    AL   121.144413     84.41      01  01779775  0400000US01
# 323       2015    ID  3201.171924     83.17      16  01779783  0400000US16
# 44        2012    AL   117.992112     81.44      01  01779775  0400000US01
# 140       2012    CO  1097.764962     79.16      08  01779779  0400000US08
# 43        2011    AL   218.923714     78.55      01  01779775  0400000US01
#
#     GEOID STUSPS      NAME LSAD         ALAND      AWATER  \
# 47     01     AL   Alabama   00  131175460655  4591915034
# 143    08     CO  Colorado   00  268418746964  1185766400
# 142    08     CO  Colorado   00  268418746964  1185766400
# 46     01     AL   Alabama   00  131175460655  4591915034
# 141    08     CO  Colorado   00  268418746964  1185766400
# 45     01     AL   Alabama   00  131175460655  4591915034
# 323    16     ID     Idaho   00  214049923496  2391577745
# 44     01     AL   Alabama   00  131175460655  4591915034
# 140    08     CO  Colorado   00  268418746964  1185766400
# 43     01     AL   Alabama   00  131175460655  4591915034
#
#                                               geometry    date_sec     colour
# 47   POLYGON ((-88.46866 31.89386, -88.46866 31.933...  1420070400  #800026ff
# 143  POLYGON ((-109.05996 38.49999, -109.05151 39.1...  1420070400  #8a0026ff
# 142  POLYGON ((-109.05996 38.49999, -109.05151 39.1...  1388534400  #900026ff
# 46   POLYGON ((-88.46866 31.89386, -88.46866 31.933...  1388534400  #900026ff
# 141  POLYGON ((-109.05996 38.49999, -109.05151 39.1...  1356998400  #970026ff
# 45   POLYGON ((-88.46866 31.89386, -88.46866 31.933...  1356998400  #a50026ff
# 323  POLYGON ((-117.24303 44.39097, -117.21507 44.4...  1420070400  #ab0026ff
# 44   POLYGON ((-88.46866 31.89386, -88.46866 31.933...  1325376000  #b50026ff
# 140  POLYGON ((-109.05996 38.49999, -109.05151 39.1...  1325376000  #bf0125ff
# 43   POLYGON ((-88.46866 31.89386, -88.46866 31.933...  1293840000  #c20225ff

# %% [markdown]
# ## 3a- Evol du nombre de feux

# %% [markdown]
# Mise en place d'une échelle de couleurs et association d'une teinte à une valeur donnée de cumsum

# %%
import branca.colormap as cm

max_colour = max(df_mega_count['cumsum'])
min_colour = min(df_mega_count['cumsum'])
#cmap = cm.linear.YlOrRd_09.scale(min_colour, max_colour)
cmap = cm.linear.Reds_09.scale(min_colour, max_colour)
df_mega_count['colour'] = df_mega_count['cumsum'].map(cmap)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\1/ipykernel_18028/1202864384.py in <module>
#       1 import branca.colormap as cm
#       2
# ----> 3 max_colour = max(df_mega_count['cumsum'])
#       4 min_colour = min(df_mega_count['cumsum'])
#       5 #cmap = cm.linear.YlOrRd_09.scale(min_colour, max_colour)
#
# NameError: name 'df_mega_count' is not defined

# %% [markdown]
# Définition d'un dictionnaire associant à chaque ID d'état, les timestamps et les teintes de couleurs

# %%
state_list = df_mega_count['NAME'].unique().tolist()
state_idx = range(len(state_list))

style_dict = {}
for i in state_idx:
    state = state_list[i]
    result = df_mega_count[df_mega_count['NAME'] == state]
    inner_dict = {}
    for _, r in result.iterrows():
        inner_dict[r['date_sec']] = {'color': r['colour'], 'opacity': 0.7}
    style_dict[str(i)] = inner_dict

# %% [markdown]
# Définition d'un objet Geopandas pour les contours des états

# %%
states_df = df_mega_count[['geometry']]
states_gdf = gpd.GeoDataFrame(states_df)
states_gdf = states_gdf.drop_duplicates().reset_index()

# %% [markdown]
# Affichage de la carte avec le TimeSlider

# %%
from folium.plugins import TimeSliderChoropleth

slider_map = folium.Map(location=[40, -95], zoom_start=4)

_ = TimeSliderChoropleth(
    data=states_gdf.to_json(),
    styledict=style_dict,

).add_to(slider_map)

_ = cmap.add_to(slider_map)
cmap.caption = "Nombre cumulé de feux reportés par état (1992-2015)"

slider_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_121c47071ce64e4098d98ea547776d48%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//d3js.org/d3.v4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_121c47071ce64e4098d98ea547776d48%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_121c47071ce64e4098d98ea547776d48%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_121c47071ce64e4098d98ea547776d48%22%2C%0A%20%20%20%20%2 ...

# %% [markdown]
# ## 3a- Evol des surfaces brûlées

# %% [markdown]
# Mise en place d'une échelle de couleurs et association d'une teinte à une valeur donnée de cumsum

# %%
import branca.colormap as cm

max_colour = max(df_mega_surf['cumsum'])
min_colour = min(df_mega_surf['cumsum'])
cmap = cm.linear.YlOrRd_09.scale(min_colour, max_colour)
df_mega_surf['colour'] = df_mega_surf['cumsum'].map(cmap)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cumsum'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\1/ipykernel_18028/535152066.py in <module>
#       1 import branca.colormap as cm
#       2
# ----> 3 max_colour = max(df_mega_surf['cumsum'])
#       4 min_colour = min(df_mega_surf['cumsum'])
#       5 cmap = cm.linear.YlOrRd_09.scale(min_colour, max_colour)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'cumsum'

# %% [markdown]
# Définition d'un dictionnaire associant à chaque ID d'état, les timestamps et les teintes de couleurs

# %%
state_list = df_mega_surf['NAME'].unique().tolist()
state_idx = range(len(state_list))

style_dict = {}
for i in state_idx:
    state = state_list[i]
    result = df_mega_surf[df_mega_surf['NAME'] == state]
    inner_dict = {}
    for _, r in result.iterrows():
        inner_dict[r['date_sec']] = {'color': r['colour'], 'opacity': 0.7}
    style_dict[str(i)] = inner_dict

# %% [markdown]
# Définition d'un objet Geopandas pour les contours des états

# %%
states_df = df_mega_surf[['geometry']]
states_gdf = gpd.GeoDataFrame(states_df)
states_gdf = states_gdf.drop_duplicates().reset_index()

# %% [markdown]
# Affichage de la carte avec le TimeSlider

# %%
from folium.plugins import TimeSliderChoropleth

slider_map = folium.Map(location=[40, -95], zoom_start=4)

_ = TimeSliderChoropleth(
    data=states_gdf.to_json(),
    styledict=style_dict,

).add_to(slider_map)

_ = cmap.add_to(slider_map)
cmap.caption = "Surfaces brûlées cumulées en km², par état, de 1992 à 2015"

slider_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_729c7c1921bf4f5ebfbfd80cc2a72401%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//d3js.org/d3.v4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_729c7c1921bf4f5ebfbfd80cc2a72401%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_729c7c1921bf4f5ebfbfd80cc2a72401%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_729c7c1921bf4f5ebfbfd80cc2a72401%22%2C%0A%20%20%20%20%2 ...

# %% [markdown]
# ## 3- Evol du pourcentage du territoire brûlé

# %% [markdown]
# Mise en place d'une échelle de couleurs et association d'une teinte à une valeur donnée de cumsum

# %%
import branca.colormap as cm

max_colour = max(df_mega_surf['cumratio'])
min_colour = min(df_mega_surf['cumratio'])
cmap = cm.linear.YlOrRd_09.scale(min_colour, max_colour)
df_mega_surf['colour'] = df_mega_surf['cumratio'].map(cmap)

# %% [markdown]
# Définition d'un dictionnaire associant à chaque ID d'état, les timestamps et les teintes de couleurs

# %%
state_list = df_mega_surf['NAME'].unique().tolist()
state_idx = range(len(state_list))

style_dict = {}
for i in state_idx:
    state = state_list[i]
    result = df_mega_surf[df_mega_surf['NAME'] == state]
    inner_dict = {}
    for _, r in result.iterrows():
        inner_dict[r['date_sec']] = {'color': r['colour'], 'opacity': 0.7}
    style_dict[str(i)] = inner_dict

# %% [markdown]
# Définition d'un objet Geopandas pour les contours des états

# %%
states_df = df_mega_surf[['geometry']]
states_gdf = gpd.GeoDataFrame(states_df)
states_gdf = states_gdf.drop_duplicates().reset_index()

# %% [markdown]
# Affichage de la carte avec le TimeSlider

# %%
from folium.plugins import TimeSliderChoropleth

slider_map = folium.Map(location=[40, -95], zoom_start=4)

_ = TimeSliderChoropleth(
    data=states_gdf.to_json(),
    styledict=style_dict,

).add_to(slider_map)

_ = cmap.add_to(slider_map)
cmap.caption = "Pourcentage cumulé de la surface brûlé, par état, de 1992 à 2015"

slider_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_7fb7c057b893498c87b929912a1defcc%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//d3js.org/d3.v4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_7fb7c057b893498c87b929912a1defcc%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_7fb7c057b893498c87b929912a1defcc%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_7fb7c057b893498c87b929912a1defcc%22%2C%0A%20%20%20%20%2 ...
